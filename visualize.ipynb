# %%
pkill -9 -f python3


`cd /OpenPCDet/tools && python3 demo.py --cfg_file /OpenPCDet/tools/cfgs/models/S/D/S_D_N.yaml --ckpt /OpenPCDet/output/OpenPCDet/tools/cfgs/models/S/D/S_D_N/unfrozen_backbone_1_94/ckpt/checkpoint_epoch_17.pth --extra_tag S_N_def --data_path /OpenPCDet/datasets/nuscenes/v1.0-mini/sweeps/LIDAR_TOP --ext .bin


cd /OpenPCDet/tools && python3 demo.py --cfg_file /OpenPCDet/tools/cfgs/models/S/D/S_D_N.yaml --ckpt /OpenPCDet/output/OpenPCDet/tools/cfgs/models/S/D/S_D_N/unfrozen_backbone_1_94/ckpt/checkpoint_epoch_17.pth --extra_tag S_N_def --data_path /OpenPCDet/datasets/nuscenes/v1.0-mini/sweeps/LIDAR_TOP --ext .bin

# %%
import subprocess
import os
def run_vis_kitti(cfg_file, ckpt, tag):
    process = subprocess.Popen(
        ['python3'    , 'demo.py',
         '--cfg_file' , cfg_file,
         '--ckpt'     , ckpt,
         '--extra_tag'  , tag, 
         '--data_path', '/OpenPCDet/datasets/kitti/testing/velodyne',
        ],
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, cwd="/OpenPCDet/tools"
    )
    for line in process.stdout:
        print(line, end='')
    process.wait()
    return process.returncode

def run_vis_nusc(cfg_file, ckpt, tag):
    process = subprocess.Popen(
        ['python3'    , 'demo.py',
         '--cfg_file' , cfg_file,
         '--ckpt'     , ckpt,
         '--extra_tag'  , tag, 
         '--data_path', '/OpenPCDet/datasets/nuscenes/v1.0-mini/sweeps/LIDAR_TOP',
         '--ext'      , '.bin'
         ],
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, cwd="/OpenPCDet/tools"
    )
    for line in process.stdout:
        print(line, end='')
    process.wait()
    return process.returncode

def run_vis_erod(cfg_file, ckpt, tag):
    process = subprocess.Popen(
        ['python3'    , 'demo.py',
         '--cfg_file' , cfg_file,
         '--ckpt'     , ckpt,
         '--extra_tag'  , tag, 
         '--data_path', '/OpenPCDet/erod/points',
         '--ext'      , '.npy'],
        stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, cwd="/OpenPCDet/tools"
    )
    for line in process.stdout:
        print(line, end='')
    process.wait()
    return process.returncode

# %%
cfg = {
    "P_D": {
        "K": "/OpenPCDet/tools/cfgs/models/P/D/P_D_K.yaml",
        "N": "/OpenPCDet/tools/cfgs/models/P/D/P_D_N.yaml",
        "E": "/OpenPCDet/tools/cfgs/models/P/D/P_D_E.yaml",
    },
    "P_T": {
        "K": "/OpenPCDet/tools/cfgs/models/P/T/P_T_K.yaml",
        "N": "/OpenPCDet/tools/cfgs/models/P/T/P_T_N.yaml",
        "E": "/OpenPCDet/tools/cfgs/models/P/T/P_T_E.yaml",
    },
    "S_D": {
        "K": "/OpenPCDet/tools/cfgs/models/S/D/S_D_K.yaml",
        "N": "/OpenPCDet/tools/cfgs/models/S/D/S_D_N.yaml",
        "E": "/OpenPCDet/tools/cfgs/models/S/D/S_D_E.yaml",
    },
    "S_F": {
        "K": "/OpenPCDet/tools/cfgs/models/S/F/S_F_K.yaml",
        "N": "/OpenPCDet/tools/cfgs/models/S/F/S_F_N.yaml",
        "E": "/OpenPCDet/tools/cfgs/models/S/F/S_F_E.yaml",
    },
    "S_T": {
        "K": "/OpenPCDet/tools/cfgs/models/S/T/S_T_K.yaml",
        "N": "/OpenPCDet/tools/cfgs/models/S/T/S_T_N.yaml",
        "E": "/OpenPCDet/tools/cfgs/models/S/T/S_T_E.yaml",
    }
}

# %%
ckpt = {
    "P_def"       :"/OpenPCDet/pcdet/models/pth/pointpillar_7728.pth", 
    "P_ftd"       :"/OpenPCDet/output/OpenPCDet/tools/cfgs/models/P/D/P_D_N/unfrozen_backbone_1/ckpt/checkpoint_epoch_27.pth",
    "S_def"       :"/OpenPCDet/pcdet/models/pth/second_7862.pth", 
    "S_ftd"       :"/OpenPCDet/output/OpenPCDet/tools/cfgs/models/S/D/S_D_N/unfrozen_backbone_1_94/ckpt/checkpoint_epoch_17.pth",    
    "S_focals_def":"/OpenPCDet/output/cfgs/models/S/F/S_F_K/default/ckpt/checkpoint_epoch_17.pth", 
    "S_focals_ftd":"/OpenPCDet/output/cfgs/models/S/F/S_F_N/default/ckpt/checkpoint_epoch_17.pth",
    }

# %% [markdown]
# ## SECOND (DEFAULT)

# %% [markdown]
# ### single

# %%
run_vis_kitti(cfg["S_D"]["K"], ckpt["S_def"], "S_D_K_def")
# Out:
# 2026-08-13 09:36:22,929   INFO  -----------------Quick Demo of OpenPCDet-------------------------
# 2026-08-13 09:36:22,940   INFO  Total number of samples: 	227
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2026-08-13 09:36:24,299   INFO  ==> Loading parameters from checkpoint /OpenPCDet/pcdet/models/pth/second_7862.pth to CPU
# 2026-08-13 09:36:24,332   INFO  ==> Done (loaded 163/163)
# 2026-08-13 09:36:25,345   INFO  Processing sample index: 	1
# 2026-08-13 09:36:28,452   INFO  Processing sample index: 	2
# 2026-08-13 09:36:28,507   INFO  Processing sample index: 	3
# 2026-08-13 09:36:28,587   INFO  Processing sample index: 	4
# 2026-08-13 09:36:28,721   INFO  Processing sample index: 	5
# 2026-08-13 09:36:28,905   INFO  Processing sample index: 	6
# 2026-08-13 09:36:29,084   INFO  Processing sample index: 	7
# 2026-08-13 09:36:29,250   INFO  Processing sample index: 	8
# 2026-08-13 09:36:29,442   INFO  Processing sample index: 	9
# 2026-08-13 09:36:29,596   INFO  Processing sample index: 	10
# 2026-08-13 09:36:29,793   INFO  Processing sample index: 	11
# 2026-08-13 09:36:29,936   INFO  Processing sample index: 	12
# 2026-08-13 09:36:30,074   INFO  Processing sample index: 	13
# 2026-08-13 09:36:30,305   INFO  Processing sample index: 	14
# 2026-08-13 09:36:30,515   INFO  Processing sample index: 	15
# 2026-08-13 09:36:30,605   INFO  Processing sample index: 	16
# 2026-08-13 09:36:30,704   INFO  Processing sample index: 	17
# 2026-08-13 09:36:30,841   INFO  Processing sample index: 	18
# 2026-08-13 09:36:30,974   INFO  Processing sample index: 	19
# 2026-08-13 09:36:31,117   INFO  Processing sample index: 	20
# 2026-08-13 09:36:31,229   INFO  Processing sample index: 	21
# 2026-08-13 09:36:31,380   INFO  Processing sample index: 	22
# 2026-08-13 09:36:31,513   INFO  Processing sample index: 	23
# 2026-08-13 09:36:31,579   INFO  Processing sample index: 	24
# 2026-08-13 09:36:31,732   INFO  Processing sample index: 	25
# 2026-08-13 09:36:31,815   INFO  Processing sample index: 	26
# 2026-08-13 09:36:31,930   INFO  Processing sample index: 	27
# 2026-08-13 09:36:32,027   INFO  Processing sample index: 	28
# 2026-08-13 09:36:32,163   INFO  Processing sample index: 	29
# 2026-08-13 09:36:32,382   INFO  Processing sample index: 	30
# 2026-08-13 09:36:32,508   INFO  Processing sample index: 	31
# 2026-08-13 09:36:32,710   INFO  Processing sample index: 	32
# 2026-08-13 09:36:32,870   INFO  Processing sample index: 	33
# 2026-08-13 09:36:33,023   INFO  Processing sample index: 	34
# 2026-08-13 09:36:33,114   INFO  Processing sample index: 	35
# 2026-08-13 09:36:33,247   INFO  Processing sample index: 	36
# 2026-08-13 09:36:33,372   INFO  Processing sample index: 	37
# 2026-08-13 09:36:33,473   INFO  Processing sample index: 	38
# 2026-08-13 09:36:33,587   INFO  Processing sample index: 	39
# 2026-08-13 09:36:33,752   INFO  Processing sample index: 	40
# 2026-08-13 09:36:33,881   INFO  Processing sample index: 	41
# 2026-08-13 09:36:34,019   INFO  Processing sample index: 	42
# 2026-08-13 09:36:34,127   INFO  Processing sample index: 	43
# 2026-08-13 09:36:34,254   INFO  Processing sample index: 	44
# 2026-08-13 09:36:34,321   INFO  Processing sample index: 	45
# 2026-08-13 09:36:34,404   INFO  Processing sample index: 	46
# 2026-08-13 09:36:34,559   INFO  Processing sample index: 	47
# 2026-08-13 09:36:34,657   INFO  Processing sample index: 	48
# 2026-08-13 09:36:34,766   INFO  Processing sample index: 	49
# 2026-08-13 09:36:34,942   INFO  Processing sample index: 	50
# 2026-08-13 09:36:35,117   INFO  Processing sample index: 	51
# 2026-08-13 09:36:35,261   INFO  Processing sample index: 	52
# 2026-08-13 09:36:35,405   INFO  Processing sample index: 	53
# 2026-08-13 09:36:35,562   INFO  Processing sample index: 	54
# 2026-08-13 09:36:35,739   INFO  Processing sample index: 	55
# 2026-08-13 09:36:35,829   INFO  Processing sample index: 	56
# 2026-08-13 09:36:35,969   INFO  Processing sample index: 	57
# 2026-08-13 09:36:36,094   INFO  Processing sample index: 	58
# 2026-08-13 09:36:36,217   INFO  Processing sample index: 	59
# 2026-08-13 09:36:36,330   INFO  Processing sample index: 	60
# 2026-08-13 09:36:36,464   INFO  Processing sample index: 	61
# 2026-08-13 09:36:36,575   INFO  Processing sample index: 	62
# 2026-08-13 09:36:36,670   INFO  Processing sample index: 	63
# 2026-08-13 09:36:36,776   INFO  Processing sample index: 	64
# 2026-08-13 09:36:36,910   INFO  Processing sample index: 	65
# 2026-08-13 09:36:37,133   INFO  Processing sample index: 	66
# 2026-08-13 09:36:37,227   INFO  Processing sample index: 	67
# 2026-08-13 09:36:37,361   INFO  Processing sample index: 	68
# 2026-08-13 09:36:37,490   INFO  Processing sample index: 	69
# 2026-08-13 09:36:37,553   INFO  Processing sample index: 	70
# 2026-08-13 09:36:37,632   INFO  Processing sample index: 	71
# 2026-08-13 09:36:37,745   INFO  Processing sample index: 	72
# 2026-08-13 09:36:37,816   INFO  Processing sample index: 	73
# 2026-08-13 09:36:37,888   INFO  Processing sample index: 	74
# 2026-08-13 09:36:37,992   INFO  Processing sample index: 	75
# 2026-08-13 09:36:38,113   INFO  Processing sample index: 	76
# 2026-08-13 09:36:38,308   INFO  Processing sample index: 	77
# 2026-08-13 09:36:38,429   INFO  Processing sample index: 	78
# 2026-08-13 09:36:38,530   INFO  Processing sample index: 	79
# 2026-08-13 09:36:38,643   INFO  Processing sample index: 	80
# 2026-08-13 09:36:38,761   INFO  Processing sample index: 	81
# 2026-08-13 09:36:38,842   INFO  Processing sample index: 	82
# 2026-08-13 09:36:38,933   INFO  Processing sample index: 	83
# 2026-08-13 09:36:39,050   INFO  Processing sample index: 	84
# 2026-08-13 09:36:39,157   INFO  Processing sample index: 	85
# 2026-08-13 09:36:39,291   INFO  Processing sample index: 	86
# 2026-08-13 09:36:39,383   INFO  Processing sample index: 	87
# 2026-08-13 09:36:39,527   INFO  Processing sample index: 	88
# 2026-08-13 09:36:39,606   INFO  Processing sample index: 	89
# 2026-08-13 09:36:39,724   INFO  Processing sample index: 	90
# 2026-08-13 09:36:39,816   INFO  Processing sample index: 	91
# 2026-08-13 09:36:39,922   INFO  Processing sample index: 	92
# 2026-08-13 09:36:40,015   INFO  Processing sample index: 	93
# 2026-08-13 09:36:40,116   INFO  Processing sample index: 	94
# 2026-08-13 09:36:40,245   INFO  Processing sample index: 	95
# 2026-08-13 09:36:40,333   INFO  Processing sample index: 	96
# 2026-08-13 09:36:40,455   INFO  Processing sample index: 	97
# 2026-08-13 09:36:40,565   INFO  Processing sample index: 	98
# 2026-08-13 09:36:40,708   INFO  Processing sample index: 	99
# 2026-08-13 09:36:40,805   INFO  Processing sample index: 	100
# 2026-08-13 09:36:40,934   INFO  Processing sample index: 	101
# 2026-08-13 09:36:41,013   INFO  Processing sample index: 	102
# 2026-08-13 09:36:41,146   INFO  Processing sample index: 	103
# 2026-08-13 09:36:41,202   INFO  Processing sample index: 	104
# 2026-08-13 09:36:41,298   INFO  Processing sample index: 	105
# 2026-08-13 09:36:41,396   INFO  Processing sample index: 	106
# 2026-08-13 09:36:41,494   INFO  Processing sample index: 	107
# 2026-08-13 09:36:41,611   INFO  Processing sample index: 	108
# 2026-08-13 09:36:41,706   INFO  Processing sample index: 	109
# 2026-08-13 09:36:41,901   INFO  Processing sample index: 	110
# 2026-08-13 09:36:42,006   INFO  Processing sample index: 	111
# 2026-08-13 09:36:42,131   INFO  Processing sample index: 	112
# 2026-08-13 09:36:42,211   INFO  Processing sample index: 	113
# 2026-08-13 09:36:42,332   INFO  Processing sample index: 	114
# 2026-08-13 09:36:42,416   INFO  Processing sample index: 	115
# 2026-08-13 09:36:42,486   INFO  Processing sample index: 	116
# 2026-08-13 09:36:42,614   INFO  Processing sample index: 	117
# 2026-08-13 09:36:42,697   INFO  Processing sample index: 	118
# 2026-08-13 09:36:42,812   INFO  Processing sample index: 	119
# 2026-08-13 09:36:42,952   INFO  Processing sample index: 	120
# 2026-08-13 09:36:43,078   INFO  Processing sample index: 	121
# 2026-08-13 09:36:43,266   INFO  Processing sample index: 	122
# 2026-08-13 09:36:43,356   INFO  Processing sample index: 	123
# 2026-08-13 09:36:43,437   INFO  Processing sample index: 	124
# 2026-08-13 09:36:43,534   INFO  Processing sample index: 	125
# 2026-08-13 09:36:43,615   INFO  Processing sample index: 	126
# 2026-08-13 09:36:43,759   INFO  Processing sample index: 	127
# 2026-08-13 09:36:43,869   INFO  Processing sample index: 	128
# 2026-08-13 09:36:44,002   INFO  Processing sample index: 	129
# 2026-08-13 09:36:44,106   INFO  Processing sample index: 	130
# 2026-08-13 09:36:44,236   INFO  Processing sample index: 	131
# 2026-08-13 09:36:44,337   INFO  Processing sample index: 	132
# 2026-08-13 09:36:44,413   INFO  Processing sample index: 	133
# 2026-08-13 09:36:44,541   INFO  Processing sample index: 	134
# 2026-08-13 09:36:44,626   INFO  Processing sample index: 	135
# 2026-08-13 09:36:44,746   INFO  Processing sample index: 	136
# 2026-08-13 09:36:44,816   INFO  Processing sample index: 	137
# 2026-08-13 09:36:44,907   INFO  Processing sample index: 	138
# 2026-08-13 09:36:44,992   INFO  Processing sample index: 	139
# 2026-08-13 09:36:45,146   INFO  Processing sample index: 	140
# 2026-08-13 09:36:45,235   INFO  Processing sample index: 	141
# 2026-08-13 09:36:45,348   INFO  Processing sample index: 	142
# 2026-08-13 09:36:45,437   INFO  Processing sample index: 	143
# 2026-08-13 09:36:45,564   INFO  Processing sample index: 	144
# 2026-08-13 09:36:45,670   INFO  Processing sample index: 	145
# 2026-08-13 09:36:45,762   INFO  Processing sample index: 	146
# 2026-08-13 09:36:45,862   INFO  Processing sample index: 	147
# 2026-08-13 09:36:45,938   INFO  Processing sample index: 	148
# 2026-08-13 09:36:46,027   INFO  Processing sample index: 	149
# 2026-08-13 09:36:46,135   INFO  Processing sample index: 	150
# 2026-08-13 09:36:46,264   INFO  Processing sample index: 	151
# 2026-08-13 09:36:46,362   INFO  Processing sample index: 	152
# 2026-08-13 09:36:46,475   INFO  Processing sample index: 	153
# 2026-08-13 09:36:46,560   INFO  Processing sample index: 	154
# 2026-08-13 09:36:46,699   INFO  Processing sample index: 	155
# 2026-08-13 09:36:46,835   INFO  Processing sample index: 	156
# 2026-08-13 09:36:46,908   INFO  Processing sample index: 	157
# 2026-08-13 09:36:46,994   INFO  Processing sample index: 	158
# 2026-08-13 09:36:47,157   INFO  Processing sample index: 	159
# 2026-08-13 09:36:47,249   INFO  Processing sample index: 	160
# 2026-08-13 09:36:47,400   INFO  Processing sample index: 	161
# 2026-08-13 09:36:47,536   INFO  Processing sample index: 	162
# 2026-08-13 09:36:47,695   INFO  Processing sample index: 	163
# 2026-08-13 09:36:47,842   INFO  Processing sample index: 	164
# 2026-08-13 09:36:48,011   INFO  Processing sample index: 	165
# 2026-08-13 09:36:48,099   INFO  Processing sample index: 	166
# 2026-08-13 09:36:48,253   INFO  Processing sample index: 	167
# 2026-08-13 09:36:48,411   INFO  Processing sample index: 	168
# 2026-08-13 09:36:48,536   INFO  Processing sample index: 	169
# 2026-08-13 09:36:48,592   INFO  Processing sample index: 	170
# 2026-08-13 09:36:48,677   INFO  Processing sample index: 	171
# 2026-08-13 09:36:48,782   INFO  Processing sample index: 	172
# 2026-08-13 09:36:48,864   INFO  Processing sample index: 	173
# 2026-08-13 09:36:48,954   INFO  Processing sample index: 	174
# 2026-08-13 09:36:49,051   INFO  Processing sample index: 	175
# 2026-08-13 09:36:49,155   INFO  Processing sample index: 	176
# 2026-08-13 09:36:49,275   INFO  Processing sample index: 	177
# 2026-08-13 09:36:49,389   INFO  Processing sample index: 	178
# 2026-08-13 09:36:49,530   INFO  Processing sample index: 	179
# 2026-08-13 09:36:49,614   INFO  Processing sample index: 	180
# 2026-08-13 09:36:49,686   INFO  Processing sample index: 	181
# 2026-08-13 09:36:49,803   INFO  Processing sample index: 	182
# 2026-08-13 09:36:49,914   INFO  Processing sample index: 	183
# 2026-08-13 09:36:50,000   INFO  Processing sample index: 	184
# 2026-08-13 09:36:50,090   INFO  Processing sample index: 	185
# 2026-08-13 09:36:50,266   INFO  Processing sample index: 	186
# 2026-08-13 09:36:50,383   INFO  Processing sample index: 	187
# 2026-08-13 09:36:50,494   INFO  Processing sample index: 	188
# 2026-08-13 09:36:50,589   INFO  Processing sample index: 	189
# 2026-08-13 09:36:50,700   INFO  Processing sample index: 	190
# 2026-08-13 09:36:50,839   INFO  Processing sample index: 	191
# 2026-08-13 09:36:50,924   INFO  Processing sample index: 	192
# 2026-08-13 09:36:50,998   INFO  Processing sample index: 	193
# 2026-08-13 09:36:51,085   INFO  Processing sample index: 	194
# 2026-08-13 09:36:51,242   INFO  Processing sample index: 	195
# 2026-08-13 09:36:51,372   INFO  Processing sample index: 	196
# 2026-08-13 09:36:51,485   INFO  Processing sample index: 	197
# 2026-08-13 09:36:51,595   INFO  Processing sample index: 	198
# 2026-08-13 09:36:51,740   INFO  Processing sample index: 	199
# 2026-08-13 09:36:51,846   INFO  Processing sample index: 	200
# 2026-08-13 09:36:51,972   INFO  Processing sample index: 	201
# 2026-08-13 09:36:52,069   INFO  Processing sample index: 	202
# 2026-08-13 09:36:52,188   INFO  Processing sample index: 	203
# 2026-08-13 09:36:52,262   INFO  Processing sample index: 	204
# 2026-08-13 09:36:52,372   INFO  Processing sample index: 	205
# 2026-08-13 09:36:52,439   INFO  Processing sample index: 	206
# 2026-08-13 09:36:52,513   INFO  Processing sample index: 	207
# 2026-08-13 09:36:52,628   INFO  Processing sample index: 	208
# 2026-08-13 09:36:52,741   INFO  Processing sample index: 	209
# 2026-08-13 09:36:52,874   INFO  Processing sample index: 	210
# 2026-08-13 09:36:52,977   INFO  Processing sample index: 	211
# 2026-08-13 09:36:53,055   INFO  Processing sample index: 	212
# 2026-08-13 09:36:53,184   INFO  Processing sample index: 	213
# 2026-08-13 09:36:53,315   INFO  Processing sample index: 	214
# 2026-08-13 09:36:53,393   INFO  Processing sample index: 	215
# 2026-08-13 09:36:53,615   INFO  Processing sample index: 	216
# 2026-08-13 09:36:53,720   INFO  Processing sample index: 	217
# 2026-08-13 09:36:53,792   INFO  Processing sample index: 	218
# 2026-08-13 09:36:53,899   INFO  Processing sample index: 	219
# 2026-08-13 09:36:53,995   INFO  Processing sample index: 	220
# 2026-08-13 09:36:54,114   INFO  Processing sample index: 	221
# 2026-08-13 09:36:54,198   INFO  Processing sample index: 	222
# 2026-08-13 09:36:54,235   INFO  Processing sample index: 	223
# 2026-08-13 09:36:54,275   INFO  Processing sample index: 	224
# 2026-08-13 09:36:54,309   INFO  Processing sample index: 	225
# 2026-08-13 09:36:54,348   INFO  Processing sample index: 	226
# 2026-08-13 09:36:54,380   INFO  Processing sample index: 	227
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000174
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000175
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000176
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000177
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000178
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000179
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000180
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000181
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000182
# 2026-08-13 09:36:54,520   INFO    Saved frame + instances -> 000183
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000184
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000185
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000186
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000187
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000188
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000189
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000190
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000191
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000192
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000193
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000194
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000195
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000196
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000197
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000198
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000199
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000200
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000201
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000202
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000203
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000204
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000205
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000206
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000207
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000208
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000209
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000210
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000211
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000212
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000213
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000214
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000215
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000216
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000217
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000218
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000219
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000220
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000221
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000222
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000223
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000224
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000225
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000226
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000227
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000228
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000229
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000230
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000231
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000232
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000233
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000234
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000235
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000236
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000237
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000238
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000239
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000240
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000241
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000242
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000243
# 2026-08-13 09:36:54,521   INFO    Saved frame + instances -> 000244
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000245
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000246
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000247
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000248
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000249
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000250
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000251
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000252
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000253
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000254
# 2026-08-13 09:36:54,522   INFO    Saved frame + instances -> 000255
# 2026-08-13 09:36:54,556   INFO    Saved frame + instances -> 000256
# 2026-08-13 09:36:54,666   INFO    Saved frame + instances -> 000257
# 2026-08-13 09:36:54,785   INFO    Saved frame + instances -> 000258
# 2026-08-13 09:36:55,147   INFO    Saved frame + instances -> 000259
# 2026-08-13 09:36:55,319   INFO    Saved frame + instances -> 000260
# 2026-08-13 09:36:55,361   INFO    Saved frame + instances -> 000261
# 2026-08-13 09:36:55,484   INFO    Saved frame + instances -> 000262
# 2026-08-13 09:36:55,831   INFO    Saved frame + instances -> 000263
# 2026-08-13 09:36:56,065   INFO    Saved frame + instances -> 000264
# 2026-08-13 09:36:56,087   INFO    Saved frame + instances -> 000265
# 2026-08-13 09:36:56,228   INFO    Saved frame + instances -> 000266
# 2026-08-13 09:36:56,608   INFO    Saved frame + instances -> 000267
# 2026-08-13 09:36:56,955   INFO    Saved frame + instances -> 000268
# 2026-08-13 09:36:56,956   INFO    Saved frame + instances -> 000269
# 2026-08-13 09:36:56,956   INFO    Saved frame + instances -> 000270
# 2026-08-13 09:36:57,520   INFO    Saved frame + instances -> 000271
# 2026-08-13 09:36:57,617   INFO    Saved frame + instances -> 000272
# 2026-08-13 09:36:58,014   INFO    Saved frame + instances -> 000273
# 2026-08-13 09:36:58,015   INFO    Saved frame + instances -> 000274
# 2026-08-13 09:36:58,226   INFO    Saved frame + instances -> 000275
# 2026-08-13 09:36:58,508   INFO    Saved frame + instances -> 000276
# 2026-08-13 09:36:58,536   INFO    Saved frame + instances -> 000277
# 2026-08-13 09:36:58,778   INFO    Saved frame + instances -> 000278
# 2026-08-13 09:36:58,868   INFO    Saved frame + instances -> 000279
# 2026-08-13 09:36:59,234   INFO    Saved frame + instances -> 000280
# 2026-08-13 09:36:59,234   INFO    Saved frame + instances -> 000281
# 2026-08-13 09:36:59,570   INFO    Saved frame + instances -> 000282
# 2026-08-13 09:36:59,570   INFO    Saved frame + instances -> 000283
# 2026-08-13 09:36:59,920   INFO    Saved frame + instances -> 000284
# 2026-08-13 09:36:59,937   INFO    Saved frame + instances -> 000285
# 2026-08-13 09:37:00,244   INFO    Saved frame + instances -> 000286
# 2026-08-13 09:37:00,293   INFO    Saved frame + instances -> 000287
# 2026-08-13 09:37:00,643   INFO    Saved frame + instances -> 000288
# 2026-08-13 09:37:00,657   INFO    Saved frame + instances -> 000289
# 2026-08-13 09:37:00,918   INFO    Saved frame + instances -> 000290
# 2026-08-13 09:37:01,054   INFO    Saved frame + instances -> 000291
# 2026-08-13 09:37:01,426   INFO    Saved frame + instances -> 000292
# 2026-08-13 09:37:01,449   INFO    Saved frame + instances -> 000293
# 2026-08-13 09:37:01,737   INFO    Saved frame + instances -> 000294
# 2026-08-13 09:37:01,994   INFO    Saved frame + instances -> 000295
# 2026-08-13 09:37:02,147   INFO    Saved frame + instances -> 000296
# 2026-08-13 09:37:02,162   INFO    Saved frame + instances -> 000297
# 2026-08-13 09:37:02,383   INFO    Saved frame + instances -> 000298
# 2026-08-13 09:37:02,816   INFO    Saved frame + instances -> 000299
# 2026-08-13 09:37:03,095   INFO    Saved frame + instances -> 000300
# 2026-08-13 09:37:03,095   INFO    Saved frame + instances -> 000301
# 2026-08-13 09:37:03,096   INFO    Saved frame + instances -> 000302
# 2026-08-13 09:37:03,735   INFO    Saved frame + instances -> 000303
# 2026-08-13 09:37:03,736   INFO    Saved frame + instances -> 000304
# 2026-08-13 09:37:03,800   INFO    Saved frame + instances -> 000305
# 2026-08-13 09:37:03,890   INFO    Saved frame + instances -> 000306
# 2026-08-13 09:37:04,518   INFO    Saved frame + instances -> 000307
# 2026-08-13 09:37:04,518   INFO    Saved frame + instances -> 000308
# 2026-08-13 09:37:04,834   INFO    Saved frame + instances -> 000309
# 2026-08-13 09:37:04,834   INFO    Saved frame + instances -> 000310
# 2026-08-13 09:37:05,176   INFO    Saved frame + instances -> 000311
# 2026-08-13 09:37:05,464   INFO    Saved frame + instances -> 000312
# 2026-08-13 09:37:05,465   INFO    Saved frame + instances -> 000313
# 2026-08-13 09:37:05,476   INFO    Saved frame + instances -> 000314
# 2026-08-13 09:37:05,879   INFO    Saved frame + instances -> 000315
# 2026-08-13 09:37:06,112   INFO    Saved frame + instances -> 000316
# 2026-08-13 09:37:06,212   INFO    Saved frame + instances -> 000317
# 2026-08-13 09:37:06,212   INFO    Saved frame + instances -> 000318
# 2026-08-13 09:37:06,599   INFO    Saved frame + instances -> 000319
# 2026-08-13 09:37:06,810   INFO    Saved frame + instances -> 000320
# 2026-08-13 09:37:06,905   INFO    Saved frame + instances -> 000321
# 2026-08-13 09:37:06,947   INFO    Saved frame + instances -> 000322
# 2026-08-13 09:37:07,282   INFO    Saved frame + instances -> 000323
# 2026-08-13 09:37:07,501   INFO    Saved frame + instances -> 000324
# 2026-08-13 09:37:07,622   INFO    Saved frame + instances -> 000325
# 2026-08-13 09:37:07,675   INFO    Saved frame + instances -> 000326
# 2026-08-13 09:37:07,958   INFO    Saved frame + instances -> 000327
# 2026-08-13 09:37:08,286   INFO    Saved frame + instances -> 000328
# 2026-08-13 09:37:08,390   INFO    Saved frame + instances -> 000329
# 2026-08-13 09:37:08,448   INFO    Saved frame + instances -> 000330
# 2026-08-13 09:37:08,755   INFO    Saved frame + instances -> 000331
# 2026-08-13 09:37:09,179   INFO    Saved frame + instances -> 000332
# 2026-08-13 09:37:09,249   INFO    Saved frame + instances -> 000333
# 2026-08-13 09:37:09,294   INFO    Saved frame + instances -> 000334
# 2026-08-13 09:37:09,580   INFO    Saved frame + instances -> 000335
# 2026-08-13 09:37:10,069   INFO    Saved frame + instances -> 000336
# 2026-08-13 09:37:10,195   INFO    Saved frame + instances -> 000337
# 2026-08-13 09:37:10,196   INFO    Saved frame + instances -> 000338
# 2026-08-13 09:37:10,734   INFO    Saved frame + instances -> 000339
# 2026-08-13 09:37:11,066   INFO    Saved frame + instances -> 000340
# 2026-08-13 09:37:11,149   INFO    Saved frame + instances -> 000341
# 2026-08-13 09:37:11,150   INFO    Saved frame + instances -> 000342
# 2026-08-13 09:37:11,461   INFO    Saved frame + instances -> 000343
# 2026-08-13 09:37:11,798   INFO    Saved frame + instances -> 000344
# 2026-08-13 09:37:11,798   INFO    Saved frame + instances -> 000345
# 2026-08-13 09:37:11,936   INFO    Saved frame + instances -> 000346
# 2026-08-13 09:37:12,165   INFO    Saved frame + instances -> 000347
# 2026-08-13 09:37:12,431   INFO    Saved frame + instances -> 000348
# 2026-08-13 09:37:12,525   INFO    Saved frame + instances -> 000349
# 2026-08-13 09:37:12,598   INFO    Saved frame + instances -> 000350
# 2026-08-13 09:37:12,932   INFO    Saved frame + instances -> 000351
# 2026-08-13 09:37:13,204   INFO    Saved frame + instances -> 000352
# 2026-08-13 09:37:13,439   INFO    Saved frame + instances -> 000353
# 2026-08-13 09:37:13,439   INFO    Saved frame + instances -> 000354
# 2026-08-13 09:37:13,765   INFO    Saved frame + instances -> 000355
# 2026-08-13 09:37:13,959   INFO    Saved frame + instances -> 000356
# 2026-08-13 09:37:14,036   INFO    Saved frame + instances -> 000357
# 2026-08-13 09:37:14,086   INFO    Saved frame + instances -> 000358
# 2026-08-13 09:37:14,446   INFO    Saved frame + instances -> 000359
# 2026-08-13 09:37:14,703   INFO    Saved frame + instances -> 000360
# 2026-08-13 09:37:14,734   INFO    Saved frame + instances -> 000361
# 2026-08-13 09:37:14,851   INFO    Saved frame + instances -> 000362
# 2026-08-13 09:37:15,200   INFO    Saved frame + instances -> 000363
# 2026-08-13 09:37:15,469   INFO    Saved frame + instances -> 000364
# 2026-08-13 09:37:15,469   INFO    Saved frame + instances -> 000365
# 2026-08-13 09:37:15,553   INFO    Saved frame + instances -> 000366
# 2026-08-13 09:37:15,865   INFO    Saved frame + instances -> 000367
# 2026-08-13 09:37:16,066   INFO    Saved frame + instances -> 000368
# 2026-08-13 09:37:16,202   INFO    Saved frame + instances -> 000369
# 2026-08-13 09:37:16,258   INFO    Saved frame + instances -> 000370
# 2026-08-13 09:37:16,565   INFO    Saved frame + instances -> 000371
# 2026-08-13 09:37:16,861   INFO    Saved frame + instances -> 000372
# 2026-08-13 09:37:17,110   INFO    Saved frame + instances -> 000373
# 2026-08-13 09:37:17,110   INFO    Saved frame + instances -> 000374
# 2026-08-13 09:37:17,539   INFO    Saved frame + instances -> 000375
# 2026-08-13 09:37:17,808   INFO    Saved frame + instances -> 000376
# 2026-08-13 09:37:17,808   INFO    Saved frame + instances -> 000377
# 2026-08-13 09:37:17,932   INFO    Saved frame + instances -> 000378
# 2026-08-13 09:37:18,255   INFO    Saved frame + instances -> 000379
# 2026-08-13 09:37:18,577   INFO    Saved frame + instances -> 000380
# 2026-08-13 09:37:18,577   INFO    Saved frame + instances -> 000381
# 2026-08-13 09:37:18,707   INFO    Saved frame + instances -> 000382
# 2026-08-13 09:37:18,954   INFO    Saved frame + instances -> 000383
# 2026-08-13 09:37:19,213   INFO    Saved frame + instances -> 000384
# 2026-08-13 09:37:19,246   INFO    Saved frame + instances -> 000385
# 2026-08-13 09:37:19,422   INFO    Saved frame + instances -> 000386
# 2026-08-13 09:37:19,782   INFO    Saved frame + instances -> 000387
# 2026-08-13 09:37:19,933   INFO    Saved frame + instances -> 000388
# 2026-08-13 09:37:19,998   INFO    Saved frame + instances -> 000389
# 2026-08-13 09:37:20,204   INFO    Saved frame + instances -> 000390
# 2026-08-13 09:37:20,454   INFO    Saved frame + instances -> 000391
# 2026-08-13 09:37:20,732   INFO    Saved frame + instances -> 000392
# 2026-08-13 09:37:20,863   INFO    Saved frame + instances -> 000393
# 2026-08-13 09:37:20,896   INFO    Saved frame + instances -> 000394
# 2026-08-13 09:37:21,143   INFO    Saved frame + instances -> 000395
# 2026-08-13 09:37:21,378   INFO    Saved frame + instances -> 000396
# 2026-08-13 09:37:21,583   INFO    Saved frame + instances -> 000397
# 2026-08-13 09:37:21,592   INFO    Saved frame + instances -> 000398
# 2026-08-13 09:37:21,804   INFO    Saved frame + instances -> 000399
# 2026-08-13 09:37:22,093   INFO    Saved frame + instances -> 000400
# 2026-08-13 09:37:22,273   INFO  Demo done. Images saved to /OpenPCDet/output/demo_images/S_D_K_def
# 0

# %%
run_vis_kitti(cfg["S_D"]["K"], ckpt["S_ftd"], "S_D_K_ftd")
# Out:
# 2026-08-13 09:37:29,946   INFO  -----------------Quick Demo of OpenPCDet-------------------------
# 2026-08-13 09:37:29,957   INFO  Total number of samples: 	227
# /usr/local/lib/python3.8/dist-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3190.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 2026-08-13 09:37:31,285   INFO  ==> Loading parameters from checkpoint /OpenPCDet/output/OpenPCDet/tools/cfgs/models/S/D/S_D_N/unfrozen_backbone_1_94/ckpt/checkpoint_epoch_17.pth to CPU
# 2026-08-13 09:37:31,317   INFO  ==> Checkpoint trained from version: pcdet+0.6.0+233f849+pyd75e03f
# 2026-08-13 09:37:31,324   INFO  ==> Done (loaded 163/163)
# 2026-08-13 09:37:32,202   INFO  Processing sample index: 	1
# 2026-08-13 09:37:35,017   INFO  Processing sample index: 	2
# 2026-08-13 09:37:35,069   INFO  Processing sample index: 	3
# 2026-08-13 09:37:35,136   INFO  Processing sample index: 	4
# 2026-08-13 09:37:35,305   INFO  Processing sample index: 	5
# 2026-08-13 09:37:35,506   INFO  Processing sample index: 	6
# 2026-08-13 09:37:35,676   INFO  Processing sample index: 	7
# 2026-08-13 09:37:35,850   INFO  Processing sample index: 	8
# 2026-08-13 09:37:36,023   INFO  Processing sample index: 	9
# 2026-08-13 09:37:36,134   INFO  Processing sample index: 	10
# 2026-08-13 09:37:36,264   INFO  Processing sample index: 	11
# 2026-08-13 09:37:36,365   INFO  Processing sample index: 	12
# 2026-08-13 09:37:36,481   INFO  Processing sample index: 	13
# 2026-08-13 09:37:36,659   INFO  Processing sample index: 	14
# 2026-08-13 09:37:36,815   INFO  Processing sample index: 	15
# 2026-08-13 09:37:36,925   INFO  Processing sample index: 	16
# 2026-08-13 09:37:37,028   INFO  Processing sample index: 	17
# 2026-08-13 09:37:37,138   INFO  Processing sample index: 	18
# 2026-08-13 09:37:37,239   INFO  Processing sample index: 	19
# 2026-08-13 09:37:37,351   INFO  Processing sample index: 	20
# 2026-08-13 09:37:37,450   INFO  Processing sample index: 	21
# 2026-08-13 09:37:37,585   INFO  Processing sample index: 	22
# 2026-08-13 09:37:37,711   INFO  Processing sample index: 	23
# 2026-08-13 09:37:37,857   INFO  Processing sample index: 	24
# 2026-08-13 09:37:37,977   INFO  Processing sample index: 	25
# 2026-08-13 09:37:38,116   INFO  Processing sample index: 	26
# 2026-08-13 09:37:38,225   INFO  Processing sample index: 	27
# 2026-08-13 09:37:38,328   INFO  Processing sample index: 	28
# 2026-08-13 09:37:38,424   INFO  Processing sample index: 	29
# 2026-08-13 09:37:38,592   INFO  Processing sample index: 	30
# 2026-08-13 09:37:38,675   INFO  Processing sample index: 	31
# 2026-08-13 09:37:38,881   INFO  Processing sample index: 	32
# 2026-08-13 09:37:39,020   INFO  Processing sample index: 	33
# 2026-08-13 09:37:39,103   INFO  Processing sample index: 	34
# 2026-08-13 09:37:39,177   INFO  Processing sample index: 	35
# 2026-08-13 09:37:39,277   INFO  Processing sample index: 	36
# 2026-08-13 09:37:39,365   INFO  Processing sample index: 	37
# 2026-08-13 09:37:39,460   INFO  Processing sample index: 	38
# 2026-08-13 09:37:39,555   INFO  Processing sample index: 	39
# 2026-08-13 09:37:39,698   INFO  Processing sample index: 	40
# 2026-08-13 09:37:39,818   INFO  Processing sample index: 	41
# 2026-08-13 09:37:39,956   INFO  Processing sample index: 	42
# 2026-08-13 09:37:40,037   INFO  Processing sample index: 	43
# 2026-08-13 09:37:40,217   INFO  Processing sample index: 	44
# 2026-08-13 09:37:40,341   INFO  Processing sample index: 	45
# 2026-08-13 09:37:40,505   INFO  Processing sample index: 	46
# 2026-08-13 09:37:40,600   INFO  Processing sample index: 	47
# 2026-08-13 09:37:40,698   INFO  Processing sample index: 	48
# 2026-08-13 09:37:40,767   INFO  Processing sample index: 	49
# 2026-08-13 09:37:40,920   INFO  Processing sample index: 	50
# 2026-08-13 09:37:41,051   INFO  Processing sample index: 	51
# 2026-08-13 09:37:41,182   INFO  Processing sample index: 	52
# 2026-08-13 09:37:41,338   INFO  Processing sample index: 	53
# 2026-08-13 09:37:41,460   INFO  Processing sample index: 	54
# 2026-08-13 09:37:41,589   INFO  Processing sample index: 	55
# 2026-08-13 09:37:41,726   INFO  Processing sample index: 	56
# 2026-08-13 09:37:41,805   INFO  Processing sample index: 	57
# 2026-08-13 09:37:41,987   INFO  Processing sample index: 	58
# 2026-08-13 09:37:42,090   INFO  Processing sample index: 	59
# 2026-08-13 09:37:42,195   INFO  Processing sample index: 	60
# 2026-08-13 09:37:42,319   INFO  Processing sample index: 	61
# 2026-08-13 09:37:42,412   INFO  Processing sample index: 	62
# 2026-08-13 09:37:42,580   INFO  Processing sample index: 	63
# 2026-08-13 09:37:42,702   INFO  Processing sample index: 	64
# 2026-08-13 09:37:42,819   INFO  Processing sample index: 	65
# 2026-08-13 09:37:42,954   INFO  Processing sample index: 	66
# 2026-08-13 09:37:43,084   INFO  Processing sample index: 	67
# 2026-08-13 09:37:43,226   INFO  Processing sample index: 	68
# 2026-08-13 09:37:43,342   INFO  Processing sample index: 	69
# 2026-08-13 09:37:43,451   INFO  Processing sample index: 	70
# 2026-08-13 09:37:43,556   INFO  Processing sample index: 	71
# 2026-08-13 09:37:43,691   INFO  Processing sample index: 	72
# 2026-08-13 09:37:43,812   INFO  Processing sample index: 	73
# 2026-08-13 09:37:43,958   INFO  Processing sample index: 	74
# 2026-08-13 09:37:44,075   INFO  Processing sample index: 	75
# 2026-08-13 09:37:44,165   INFO  Processing sample index: 	76
# 2026-08-13 09:37:44,289   INFO  Processing sample index: 	77
# 2026-08-13 09:37:44,400   INFO  Processing sample index: 	78
# 2026-08-13 09:37:44,510   INFO  Processing sample index: 	79
# 2026-08-13 09:37:44,636   INFO  Processing sample index: 	80
# 2026-08-13 09:37:44,731   INFO  Processing sample index: 	81
# 2026-08-13 09:37:44,879   INFO  Processing sample index: 	82
# 2026-08-13 09:37:44,997   INFO  Processing sample index: 	83
# 2026-08-13 09:37:45,125   INFO  Processing sample index: 	84
# 2026-08-13 09:37:45,272   INFO  Processing sample index: 	85
# 2026-08-13 09:37:45,410   INFO  Processing sample index: 	86
# 2026-08-13 09:37:45,542   INFO  Processing sample index: 	87
# 2026-08-13 09:37:45,661   INFO  Processing sample index: 	88
# 2026-08-13 09:37:45,823   INFO  Processing sample index: 	89
# 2026-08-13 09:37:45,976   INFO  Processing sample index: 	90
# 2026-08-13 09:37:46,098   INFO  Processing sample index: 	91
# 2026-08-13 09:37:46,215   INFO  Processing sample index: 	92
# 2026-08-13 09:37:46,371   INFO  Processing sample index: 	93
# 2026-08-13 09:37:46,484   INFO  Processing sample index: 	94
# 2026-08-13 09:37:46,596   INFO  Processing sample index: 	95
# 2026-08-13 09:37:46,661   INFO  Processing sample index: 	96
# 2026-08-13 09:37:46,820   INFO  Processing sample index: 	97
# 2026-08-13 09:37:46,937   INFO  Processing sample index: 	98
# 2026-08-13 09:37:47,011   INFO  Processing sample index: 	99
# 2026-08-13 09:37:47,125   INFO  Processing sample index: 	100
# 2026-08-13 09:37:47,229   INFO  Processing sample index: 	101
# 2026-08-13 09:37:47,301   INFO  Processing sample index: 	102
# 2026-08-13 09:37:47,401   INFO  Processing sample index: 	103
# 2026-08-13 09:37:47,524   INFO  Processing sample index: 	104
# 2026-08-13 09:37:47,676   INFO  Processing sample index: 	105
# 2026-08-13 09:37:47,786   INFO  Processing sample index: 	106
# 2026-08-13 09:37:47,888   INFO  Processing sample index: 	107
# 2026-08-13 09:37:47,977   INFO  Processing sample index: 	108
# 2026-08-13 09:37:48,069   INFO  Processing sample index: 	109
# 2026-08-13 09:37:48,188   INFO  Processing sample index: 	110
# 2026-08-13 09:37:48,300   INFO  Processing sample index: 	111
# 2026-08-13 09:37:48,410   INFO  Processing sample index: 	112
# 2026-08-13 09:37:48,485   INFO  Processing sample index: 	113
# 2026-08-13 09:37:48,588   INFO  Processing sample index: 	114
# 2026-08-13 09:37:48,678   INFO  Processing sample index: 	115
# 2026-08-13 09:37:48,797   INFO  Processing sample index: 	116
# 2026-08-13 09:37:48,942   INFO  Processing sample index: 	117
# 2026-08-13 09:37:49,043   INFO  Processing sample index: 	118
# 2026-08-13 09:37:49,157   INFO  Processing sample index: 	119
# 2026-08-13 09:37:49,255   INFO  Processing sample index: 	120
# 2026-08-13 09:37:49,377   INFO  Processing sample index: 	121
# 2026-08-13 09:37:49,492   INFO  Processing sample index: 	122
# 2026-08-13 09:37:49,611   INFO  Processing sample index: 	123
# 2026-08-13 09:37:49,694   INFO  Processing sample index: 	124
# 2026-08-13 09:37:49,784   INFO  Processing sample index: 	125
# 2026-08-13 09:37:49,888   INFO  Processing sample index: 	126
# 2026-08-13 09:37:49,998   INFO  Processing sample index: 	127
# 2026-08-13 09:37:50,107   INFO  Processing sample index: 	128
# 2026-08-13 09:37:50,220   INFO  Processing sample index: 	129
# 2026-08-13 09:37:50,338   INFO  Processing sample index: 	130
# 2026-08-13 09:37:50,478   INFO  Processing sample index: 	131
# 2026-08-13 09:37:50,605   INFO  Processing sample index: 	132
# 2026-08-13 09:37:50,685   INFO  Processing sample index: 	133
# 2026-08-13 09:37:50,786   INFO  Processing sample index: 	134
# 2026-08-13 09:37:50,875   INFO  Processing sample index: 	135
# 2026-08-13 09:37:50,991   INFO  Processing sample index: 	136
# 2026-08-13 09:37:51,106   INFO  Processing sample index: 	137
# 2026-08-13 09:37:51,202   INFO  Processing sample index: 	138
# 2026-08-13 09:37:51,324   INFO  Processing sample index: 	139
# 2026-08-13 09:37:51,456   INFO  Processing sample index: 	140
# 2026-08-13 09:37:51,548   INFO  Processing sample index: 	141
# 2026-08-13 09:37:51,678   INFO  Processing sample index: 	142
# 2026-08-13 09:37:51,766   INFO  Processing sample index: 	143
# 2026-08-13 09:37:51,866   INFO  Processing sample index: 	144
# 2026-08-13 09:37:51,992   INFO  Processing sample index: 	145
# 2026-08-13 09:37:52,142   INFO  Processing sample index: 	146
# 2026-08-13 09:37:52,317   INFO  Processing sample index: 	147
# 2026-08-13 09:37:52,475   INFO  Processing sample index: 	148
# 2026-08-13 09:37:52,622   INFO  Processing sample index: 	149
# 2026-08-13 09:37:52,775   INFO  Processing sample index: 	150
# 2026-08-13 09:37:52,949   INFO  Processing sample index: 	151
# 2026-08-13 09:37:53,037   INFO  Processing sample index: 	152
# 2026-08-13 09:37:53,134   INFO  Processing sample index: 	153
# 2026-08-13 09:37:53,272   INFO  Processing sample index: 	154
# 2026-08-13 09:37:53,399   INFO  Processing sample index: 	155
# 2026-08-13 09:37:53,515   INFO  Processing sample index: 	156
# 2026-08-13 09:37:53,621   INFO  Processing sample index: 	157
# 2026-08-13 09:37:53,710   INFO  Processing sample index: 	158
# 2026-08-13 09:37:53,816   INFO  Processing sample index: 	159
# 2026-08-13 09:37:53,924   INFO  Processing sample index: 	160
# 2026-08-13 09:37:54,015   INFO  Processing sample index: 	161
# 2026-08-13 09:37:54,134   INFO  Processing sample index: 	162
# 2026-08-13 09:37:54,271   INFO  Processing sample index: 	163
# 2026-08-13 09:37:54,357   INFO  Processing sample index: 	164
# 2026-08-13 09:37:54,439   INFO  Processing sample index: 	165
# 2026-08-13 09:37:54,534   INFO  Processing sample index: 	166
# 2026-08-13 09:37:54,664   INFO  Processing sample index: 	167
# 2026-08-13 09:37:54,727   INFO  Processing sample index: 	168
# 2026-08-13 09:37:54,846   INFO  Processing sample index: 	169
# 2026-08-13 09:37:54,953   INFO  Processing sample index: 	170
# 2026-08-13 09:37:55,117   INFO  Processing sample index: 	171
# 2026-08-13 09:37:55,206   INFO  Processing sample index: 	172
# 2026-08-13 09:37:55,374   INFO  Processing sample index: 	173
# 2026-08-13 09:37:55,548   INFO  Processing sample index: 	174
# 2026-08-13 09:37:55,688   INFO  Processing sample index: 	175
# 2026-08-13 09:37:55,810   INFO  Processing sample index: 	176
# 2026-08-13 09:37:55,983   INFO  Processing sample index: 	177
# 2026-08-13 09:37:56,092   INFO  Processing sample index: 	178
# 2026-08-13 09:37:56,233   INFO  Processing sample index: 	179
# 2026-08-13 09:37:56,354   INFO  Processing sample index: 	180
# 2026-08-13 09:37:56,494   INFO  Processing sample index: 	181
# 2026-08-13 09:37:56,626   INFO  Processing sample index: 	182
# 2026-08-13 09:37:56,839   INFO  Processing sample index: 	183
# 2026-08-13 09:37:56,926   INFO  Processing sample index: 	184
# 2026-08-13 09:37:57,102   INFO  Processing sample index: 	185
# 2026-08-13 09:37:57,190   INFO  Processing sample index: 	186
# 2026-08-13 09:37:57,390   INFO  Processing sample index: 	187
# 2026-08-13 09:37:57,509   INFO  Processing sample index: 	188
# 2026-08-13 09:37:57,614   INFO  Processing sample index: 	189
# 2026-08-13 09:37:57,748   INFO  Processing sample index: 	190
# 2026-08-13 09:37:57,974   INFO  Processing sample index: 	191
# 2026-08-13 09:37:58,085   INFO  Processing sample index: 	192
# 2026-08-13 09:37:58,221   INFO  Processing sample index: 	193
# 2026-08-13 09:37:58,426   INFO  Processing sample index: 	194
# 2026-08-13 09:37:58,590   INFO  Processing sample index: 	195
# 2026-08-13 09:37:58,715   INFO  Processing sample index: 	196
# 2026-08-13 09:37:58,842   INFO  Processing sample index: 	197
# 2026-08-13 09:37:58,965   INFO  Processing sample index: 	198
# 2026-08-13 09:37:59,125   INFO  Processing sample index: 	199
# 2026-08-13 09:37:59,254   INFO  Processing sample index: 	200
# 2026-08-13 09:37:59,362   INFO  Processing sample index: 	201
# 2026-08-13 09:37:59,525   INFO  Processing sample index: 	202
# 2026-08-13 09:37:59,680   INFO  Processing sample index: 	203
# 2026-08-13 09:37:59,848   INFO  Processing sample index: 	204
# 2026-08-13 09:37:59,978   INFO  Processing sample index: 	205
# 2026-08-13 09:38:00,071   INFO  Processing sample index: 	206
# 2026-08-13 09:38:00,209   INFO  Processing sample index: 	207
# 2026-08-13 09:38:00,354   INFO  Processing sample index: 	208
# 2026-08-13 09:38:00,473   INFO  Processing sample index: 	209
# 2026-08-13 09:38:00,588   INFO  Processing sample index: 	210
# 2026-08-13 09:38:00,700   INFO  Processing sample index: 	211
# 2026-08-13 09:38:00,804   INFO  Processing sample index: 	212
# 2026-08-13 09:38:00,891   INFO  Processing sample index: 	213
# 2026-08-13 09:38:00,978   INFO  Processing sample index: 	214
# 2026-08-13 09:38:01,116   INFO  Processing sample index: 	215
# 2026-08-13 09:38:01,256   INFO  Processing sample index: 	216
# 2026-08-13 09:38:01,409   INFO  Processing sample index: 	217
# 2026-08-13 09:38:01,561   INFO  Processing sample index: 	218
# 2026-08-13 09:38:01,674   INFO  Processing sample index: 	219
# 2026-08-13 09:38:01,831   INFO  Processing sample index: 	220
# 2026-08-13 09:38:01,942   INFO  Processing sample index: 	221
# 2026-08-13 09:38:02,040   INFO  Processing sample index: 	222
# 2026-08-13 09:38:02,133   INFO  Processing sample index: 	223
# 2026-08-13 09:38:02,178   INFO  Processing sample index: 	224
# 2026-08-13 09:38:02,222   INFO  Processing sample index: 	225
# 2026-08-13 09:38:02,269   INFO  Processing sample index: 	226
# 2026-08-13 09:38:02,313   INFO  Processing sample index: 	227
# 2026-08-13 09:38:02,560   INFO    Saved frame + instances -> 000174
# 2026-08-13 09:38:02,560   INFO    Saved frame + instances -> 000175
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000176
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000177
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000178
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000179
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000180
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000181
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000182
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000183
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000184
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000185
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000186
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000187
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000188
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000189
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000190
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000191
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000192
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000193
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000194
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000195
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000196
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000197
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000198
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000199
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000200
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000201
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000202
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000203
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000204
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000205
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000206
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000207
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000208
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000209
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000210
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000211
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000212
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000213
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000214
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000215
# 2026-08-13 09:38:02,561   INFO    Saved frame + instances -> 000216
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000217
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000218
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000219
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000220
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000221
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000222
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000223
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000224
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000225
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000226
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000227
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000228
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000229
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000230
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000231
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000232
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000233
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000234
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000235
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000236
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000237
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000238
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000239
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000240
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000241
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000242
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000243
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000244
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000245
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000246
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000247
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000248
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000249
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000250
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000251
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000252
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000253
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000254
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000255
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000256
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000257
# 2026-08-13 09:38:02,562   INFO    Saved frame + instances -> 000258
# 2026-08-13 09:38:02,706   INFO    Saved frame + instances -> 000259
# 2026-08-13 09:38:03,092   INFO    Saved frame + instances -> 000260
# 2026-08-13 09:38:03,092   INFO    Saved frame + instances -> 000261
# 2026-08-13 09:38:03,289   INFO    Saved frame + instances -> 000262
# 2026-08-13 09:38:03,491   INFO    Saved frame + instances -> 000263
# 2026-08-13 09:38:03,952   INFO    Saved frame + instances -> 000264
# 2026-08-13 09:38:03,975   INFO    Saved frame + instances -> 000265
# 2026-08-13 09:38:04,107   INFO    Saved frame + instances -> 000266
# 2026-08-13 09:38:04,513   INFO    Saved frame + instances -> 000267
# 2026-08-13 09:38:04,964   INFO    Saved frame + instances -> 000268
# 2026-08-13 09:38:04,964   INFO    Saved frame + instances -> 000269
# 2026-08-13 09:38:04,965   INFO    Saved frame + instances -> 000270
# 2026-08-13 09:38:05,350   INFO    Saved frame + instances -> 000271
# 2026-08-13 09:38:05,607   INFO    Saved frame + instances -> 000272
# 2026-08-13 09:38:05,925   INFO    Saved frame + instances -> 000273
# 2026-08-13 09:38:05,925   INFO    Saved frame + instances -> 000274
# 2026-08-13 09:38:06,101   INFO    Saved frame + instances -> 000275
# 2026-08-13 09:38:06,399   INFO    Saved frame + instances -> 000276
# 2026-08-13 09:38:06,644   INFO    Saved frame + instances -> 000277
# 2026-08-13 09:38:06,743   INFO    Saved frame + instances -> 000278
# 2026-08-13 09:38:06,803   INFO    Saved frame + instances -> 000279
# 2026-08-13 09:38:07,175   INFO    Saved frame + instances -> 000280
# 2026-08-13 09:38:07,419   INFO    Saved frame + instances -> 000281
# 2026-08-13 09:38:07,572   INFO    Saved frame + instances -> 000282
# 2026-08-13 09:38:07,573   INFO    Saved frame + instances -> 000283
# 2026-08-13 09:38:07,921   INFO    Saved frame + instances -> 000284
# 2026-08-13 09:38:08,120   INFO    Saved frame + instances -> 000285
# 2026-08-13 09:38:08,308   INFO    Saved frame + instances -> 000286
# 2026-08-13 09:38:08,350   INFO    Saved frame + instances -> 000287
# 2026-08-13 09:38:08,674   INFO    Saved frame + instances -> 000288
# 2026-08-13 09:38:08,869   INFO    Saved frame + instances -> 000289
# 2026-08-13 09:38:09,000   INFO    Saved frame + instances -> 000290
# 2026-08-13 09:38:09,120   INFO    Saved frame + instances -> 000291
# 2026-08-13 09:38:09,566   INFO    Saved frame + instances -> 000292
# 2026-08-13 09:38:09,647   INFO    Saved frame + instances -> 000293
# 2026-08-13 09:38:09,781   INFO    Saved frame + instances -> 000294
# 2026-08-13 09:38:10,013   INFO    Saved frame + instances -> 000295
# 2026-08-13 09:38:10,300   INFO    Saved frame + instances -> 000296
# 2026-08-13 09:38:10,428   INFO    Saved frame + instances -> 000297
# 2026-08-13 09:38:10,459   INFO    Saved frame + instances -> 000298
# 2026-08-13 09:38:10,821   INFO    Saved frame + instances -> 000299
# 2026-08-13 09:38:10,966   INFO    Saved frame + instances -> 000300
# 2026-08-13 09:38:11,373   INFO    Saved frame + instances -> 000301
# 2026-08-13 09:38:11,373   INFO    Saved frame + instances -> 000302
# 2026-08-13 09:38:11,693   INFO    Saved frame + instances -> 000303
# 2026-08-13 09:38:11,732   INFO    Saved frame + instances -> 000304
# 2026-08-13 09:38:12,001   INFO    Saved frame + instances -> 000305
# 2026-08-13 09:38:12,154   INFO    Saved frame + instances -> 000306
# 2026-08-13 09:38:12,419   INFO    Saved frame + instances -> 000307
# 2026-08-13 09:38:12,433   INFO    Saved frame + instances -> 000308
# 2026-08-13 09:38:12,776   INFO    Saved frame + instances -> 000309
# 2026-08-13 09:38:12,886   INFO    Saved frame + instances -> 000310
# 2026-08-13 09:38:13,136   INFO    Saved frame + instances -> 000311
# 2026-08-13 09:38:13,217   INFO    Saved frame + instances -> 000312
# 2026-08-13 09:38:13,504   INFO    Saved frame + instances -> 000313
# 2026-08-13 09:38:13,613   INFO    Saved frame + instances -> 000314
# 2026-08-13 09:38:13,877   INFO    Saved frame + instances -> 000315
# 2026-08-13 09:38:13,911   INFO    Saved frame + instances -> 000316
# 2026-08-13 09:38:14,210   INFO    Saved frame + instances -> 000317
# 2026-08-13 09:38:14,324   INFO    Saved frame + instances -> 000318
# 2026-08-13 09:38:14,683   INFO    Saved frame + instances -> 000319
# 2026-08-13 09:38:14,683   INFO    Saved frame + instances -> 000320
# 2026-08-13 09:38:14,931   INFO    Saved frame + instances -> 000321
# 2026-08-13 09:38:15,074   INFO    Saved frame + instances -> 000322
# 2026-08-13 09:38:15,414   INFO    Saved frame + instances -> 000323
# 2026-08-13 09:38:15,414   INFO    Saved frame + instances -> 000324
# 2026-08-13 09:38:15,649   INFO    Saved frame + instances -> 000325
# 2026-08-13 09:38:15,853   INFO    Saved frame + instances -> 000326
# 2026-08-13 09:38:16,111   INFO    Saved frame + instances -> 000327
# 2026-08-13 09:38:16,146   INFO    Saved frame + instances -> 000328
# 2026-08-13 09:38:16,384   INFO    Saved frame + instances -> 000329
# 2026-08-13 09:38:16,610   INFO    Saved frame + instances -> 000330
# 2026-08-13 09:38:17,015   INFO    Saved frame + instances -> 000331
# 2026-08-13 09:38:17,108   INFO    Saved frame + instances -> 000332
# 2026-08-13 09:38:17,116   INFO    Saved frame + instances -> 000333
# 2026-08-13 09:38:17,346   INFO    Saved frame + instances -> 000334
# 2026-08-13 09:38:17,735   INFO    Saved frame + instances -> 000335
# 2026-08-13 09:38:17,841   INFO    Saved frame + instances -> 000336
# 2026-08-13 09:38:18,144   INFO    Saved frame + instances -> 000337
# 2026-08-13 09:38:18,244   INFO    Saved frame + instances -> 000338
# 2026-08-13 09:38:18,449   INFO    Saved frame + instances -> 000339
# 2026-08-13 09:38:18,545   INFO    Saved frame + instances -> 000340
# 2026-08-13 09:38:18,866   INFO    Saved frame + instances -> 000341
# 2026-08-13 09:38:18,934   INFO    Saved frame + instances -> 000342
# 2026-08-13 09:38:19,175   INFO    Saved frame + instances -> 000343
# 2026-08-13 09:38:19,249   INFO    Saved frame + instances -> 000344
# 2026-08-13 09:38:19,508   INFO    Saved frame + instances -> 000345
# 2026-08-13 09:38:19,646   INFO    Saved frame + instances -> 000346
# 2026-08-13 09:38:19,883   INFO    Saved frame + instances -> 000347
# 2026-08-13 09:38:19,975   INFO    Saved frame + instances -> 000348
# 2026-08-13 09:38:20,185   INFO    Saved frame + instances -> 000349
# 2026-08-13 09:38:20,311   INFO    Saved frame + instances -> 000350
# 2026-08-13 09:38:20,603   INFO    Saved frame + instances -> 000351
# 2026-08-13 09:38:20,771   INFO    Saved frame + instances -> 000352
# 2026-08-13 09:38:20,867   INFO    Saved frame + instances -> 000353
# 2026-08-13 09:38:21,029   INFO    Saved frame + instances -> 000354
# 2026-08-13 09:38:21,369   INFO    Saved frame + instances -> 000355
# 2026-08-13 09:38:21,650   INFO    Saved frame + instances -> 000356
# 2026-08-13 09:38:21,651   INFO    Saved frame + instances -> 000357
# 2026-08-13 09:38:21,791   INFO    Saved frame + instances -> 000358
# 2026-08-13 09:38:22,057   INFO    Saved frame + instances -> 000359
# 2026-08-13 09:38:22,293   INFO    Saved frame + instances -> 000360
# 2026-08-13 09:38:22,344   INFO    Saved frame + instances -> 000361
# 2026-08-13 09:38:22,537   INFO    Saved frame + instances -> 000362
# 2026-08-13 09:38:22,779   INFO    Saved frame + instances -> 000363
# 2026-08-13 09:38:23,062   INFO    Saved frame + instances -> 000364
# 2026-08-13 09:38:23,196   INFO    Saved frame + instances -> 000365
# 2026-08-13 09:38:23,222   INFO    Saved frame + instances -> 000366
# 2026-08-13 09:38:23,628   INFO    Saved frame + instances -> 000367
# 2026-08-13 09:38:23,737   INFO    Saved frame + instances -> 000368
# 2026-08-13 09:38:23,970   INFO    Saved frame + instances -> 000369
# 2026-08-13 09:38:23,970   INFO    Saved frame + instances -> 000370
# 2026-08-13 09:38:24,316   INFO    Saved frame + instances -> 000371
# 2026-08-13 09:38:24,610   INFO    Saved frame + instances -> 000372
# 2026-08-13 09:38:24,898   INFO    Saved frame + instances -> 000373
# 2026-08-13 09:38:24,898   INFO    Saved frame + instances -> 000374
# 2026-08-13 09:38:25,049   INFO    Saved frame + instances -> 000375
# 2026-08-13 09:38:25,342   INFO    Saved frame + instances -> 000376
# 2026-08-13 09:38:25,409   INFO    Saved frame + instances -> 000377
# 2026-08-13 09:38:25,639   INFO    Saved frame + instances -> 000378
# 2026-08-13 09:38:25,722   INFO    Saved frame + instances -> 000379
# 2026-08-13 09:38:26,044   INFO    Saved frame + instances -> 000380
# 2026-08-13 09:38:26,084   INFO    Saved frame + instances -> 000381
# 2026-08-13 09:38:26,377   INFO    Saved frame + instances -> 000382
# 2026-08-13 09:38:26,397   INFO    Saved frame + instances -> 000383
# 2026-08-13 09:38:26,722   INFO    Saved frame + instances -> 000384
# 2026-08-13 09:38:26,783   INFO    Saved frame + instances -> 000385
# 2026-08-13 09:38:27,178   INFO    Saved frame + instances -> 000386
# 2026-08-13 09:38:27,178   INFO    Saved frame + instances -> 000387
# 2026-08-13 09:38:27,383   INFO    Saved frame + instances -> 000388
# 2026-08-13 09:38:27,482   INFO    Saved frame + instances -> 000389
# 2026-08-13 09:38:27,888   INFO    Saved frame + instances -> 000390
# 2026-08-13 09:38:27,924   INFO    Saved frame + instances -> 000391
# 2026-08-13 09:38:28,206   INFO    Saved frame + instances -> 000392
# 2026-08-13 09:38:28,221   INFO    Saved frame + instances -> 000393
# 2026-08-13 09:38:28,609   INFO    Saved frame + instances -> 000394
# 2026-08-13 09:38:28,708   INFO    Saved frame + instances -> 000395
# 2026-08-13 09:38:28,960   INFO    Saved frame + instances -> 000396
# 2026-08-13 09:38:29,256   INFO    Saved frame + instances -> 000397
# 2026-08-13 09:38:29,662   INFO    Saved frame + instances -> 000398
# 2026-08-13 09:38:29,662   INFO    Saved frame + instances -> 000399
# 2026-08-13 09:38:29,770   INFO    Saved frame + instances -> 000400
# 2026-08-13 09:38:29,955   INFO  Demo done. Images saved to /OpenPCDet/output/demo_images/S_D_K_ftd
# 0

# %%
run_vis_nusc(cfg["S_D"]["N"], ckpt["S_def"], "S_D_N_def")
# Out:
# usage: demo.py [-h] [--cfg_file CFG_FILE] [--data_path DATA_PATH]
#                [--ckpt CKPT] [--ext EXT] [--extra_tag EXTRA_TAG] [--realtime]
#                [--workers WORKERS] [--score_thresh SCORE_THRESH]
#                [--nms_thresh NMS_THRESH] [--nms_post_maxsize NMS_POST_MAXSIZE]
# demo.py: error: unrecognized arguments: extra_tag S_D_N_def
# 2

# %%
run_vis_nusc(cfg["S_D"]["N"], ckpt["S_ftd"], "S_D_N_ftd")
# Out:
# usage: demo.py [-h] [--cfg_file CFG_FILE] [--data_path DATA_PATH]
#                [--ckpt CKPT] [--ext EXT] [--extra_tag EXTRA_TAG] [--realtime]
#                [--workers WORKERS] [--score_thresh SCORE_THRESH]
#                [--nms_thresh NMS_THRESH] [--nms_post_maxsize NMS_POST_MAXSIZE]
# demo.py: error: unrecognized arguments: extra_tag S_D_N_ftd
# 2

# %%
run_vis_erod(cfg["S_D"]["E"], ckpt["S_def"], "S_D_E_def")
# Out:
# usage: demo.py [-h] [--cfg_file CFG_FILE] [--data_path DATA_PATH]
#                [--ckpt CKPT] [--ext EXT] [--extra_tag EXTRA_TAG] [--realtime]
#                [--workers WORKERS] [--score_thresh SCORE_THRESH]
#                [--nms_thresh NMS_THRESH] [--nms_post_maxsize NMS_POST_MAXSIZE]
# demo.py: error: unrecognized arguments: extra_tag S_D_E_def
# 2

# %%
run_vis_erod(cfg["S_D"]["E"], ckpt["S_ftd"], "S_D_E_ftd")
# Out:
# usage: demo.py [-h] [--cfg_file CFG_FILE] [--data_path DATA_PATH]
#                [--ckpt CKPT] [--ext EXT] [--extra_tag EXTRA_TAG] [--realtime]
#                [--workers WORKERS] [--score_thresh SCORE_THRESH]
#                [--nms_thresh NMS_THRESH] [--nms_post_maxsize NMS_POST_MAXSIZE]
# demo.py: error: unrecognized arguments: extra_tag S_D_E_ftd
# 2

# %% [markdown]
# ## SECOND (FOCALS)

# %% [markdown]
# ### single

# %%
run_vis_kitti(cfg["S_F"]["K"], ckpt["S_def"], "S_F_K_def")

# %%
run_vis_kitti(cfg["S_F"]["K"], ckpt["S_ftd"], "S_F_K_ftd")

# %%
run_vis_nusc(cfg["S_F"]["N"], ckpt["S_def"], "S_F_N_def")

# %%
run_vis_nusc(cfg["S_F"]["N"], ckpt["S_ftd"], "S_F_N_ftd")

# %%
run_vis_erod(cfg["S_F"]["E"], ckpt["S_def"], "S_F_E_def")

# %%
run_vis_erod(cfg["S_F"]["E"], ckpt["S_ftd"], "S_F_E_ftd")

# %% [markdown]
# ## SECOND (TENT)

# %% [markdown]
# ### single

# %%
run_vis_kitti(cfg["S_T"]["K"], ckpt["S_def"], "S_T_K_def")

# %%
run_vis_kitti(cfg["S_T"]["K"], ckpt["S_ftd"], "S_T_K_ftd")

# %%
run_vis_nusc(cfg["S_T"]["N"], ckpt["S_def"], "S_T_N_def")

# %%
run_vis_nusc(cfg["S_T"]["N"], ckpt["S_ftd"], "S_T_N_ftd")

# %%
run_vis_erod(cfg["S_T"]["E"], ckpt["S_def"], "S_T_E_def")

# %%
run_vis_erod(cfg["S_T"]["E"], ckpt["S_ftd"], "S_T_E_ftd")

# %% [markdown]
# ## PointPillars (DEFAULT)

# %% [markdown]
# ### single

# %%
run_vis_kitti(cfg["P_D"]["K"], ckpt["P_def"], "P_D_K_def")

# %%
run_vis_kitti(cfg["P_D"]["K"], ckpt["P_ftd"], "P_D_K_ftd")

# %%
run_vis_nusc(cfg["P_D"]["N"], ckpt["P_def"], "P_D_N_def")

# %%
run_vis_nusc(cfg["P_D"]["N"], ckpt["P_ftd"], "P_D_N_ftd")

# %%
run_vis_erod(cfg["P_D"]["E"], ckpt["P_def"], "P_D_E_def")

# %%
run_vis_erod(cfg["P_D"]["E"], ckpt["P_ftd"], "P_D_E_ftd")

# %% [markdown]
# ## PointPillars (TENT)

# %% [markdown]
# ### single

# %%
run_vis_kitti(cfg["P_T"]["K"], ckpt["P_def"], "P_T_K_def")

# %%
run_vis_kitti(cfg["P_T"]["K"], ckpt["P_ftd"], "P_T_K_ftd")

# %%
run_vis_nusc(cfg["P_T"]["N"], ckpt["P_def"], "P_T_N_def")

# %%
run_vis_nusc(cfg["P_T"]["N"], ckpt["P_ftd"], "P_T_N_ftd")

# %%
run_vis_erod(cfg["P_T"]["E"], ckpt["P_def"], "P_T_E_def")

# %%
run_vis_erod(cfg["P_T"]["E"], ckpt["P_ftd"], "P_T_E_def")
